# %% [markdown]
# # Tools for Data science peer graded assignment

# %% [markdown]
# **Yimeng Wang**
# - Data Scientist

# %% [markdown]
# *I am interested in data science because I love data and felt rewarded after running the model. Python is a very cool language too.*

# %% [markdown]
# ### I would like to do some basic calculations

# %%
print(12*24+48)
# Out:
# 336

# %% [markdown]
# ## steps for correlation
# --------------------------------------------------
#  - Determine your data sets.
#  - Calculate the standardized value for your x variables.
#  - Calculate the standardized value for your y variables.
#  - Multiply and find the sum
#  - Divide the sum and determine the correlation coefficient
#
#  ![McQueen](https://en.wikipedia.org/wiki/Lightning_McQueen#/media/File:Lightning_McQueen.png"Logo Title Text 1")
